# %% [markdown]
# # KNN Algorithm

# %% [raw]
# 1. It is supervised machine laerning algorithm.
# 2. KNN used for both regression and classification.
# 3. K-Nearest Neighbour is one of the simplest machine Learning algorithms based on supervised machine learning technique.
# 4. K-NN algorithm can be used for Regression as well as for classification but mostly it is used to the classification        problems.
# 5. It is also called as voting classifiers.
# 6. Distance based algonthm, it is a non probabilistic algorithm.
# 7. It is also called as lazy learner.
# 8. because it does not learn from the training set immediatly instead to store the datasets and at the
#    time of classification, it performs on action of dataset.
# 9. It is also bcz it slow take a lot of time calculating the distances with each sample.
# 10. voting classifier is used to devote class to the testing valves.

# %% [markdown]
# # Formula for Distance Calculations :

# %% [markdown]
# Euclidean Distance :
# ![image.png](attachment:image.png)

# %% [markdown]
# Manhattan Distance :
# ![image.png](attachment:image.png)

# %% [markdown]
# # KNN Regression

# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([[10,20,30,40,50],[12,13,41,67,43],[1000,2000,3000,4000,5000]])
df=pd.DataFrame(arr)
df=df.T
df
# Out:
#     0   1     2
# 0  10  12  1000
# 1  20  13  2000
# 2  30  41  3000
# 3  40  67  4000
# 4  50  43  5000

# %%
df.rename({0:'Experience',1:'Age',2:'Income'},axis=1,inplace=True)
df
# Out:
#    Experience  Age  Income
# 0          10   12    1000
# 1          20   13    2000
# 2          30   41    3000
# 3          40   67    4000
# 4          50   43    5000

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Experience',y='Age',data=df)
# Out:
# <Axes: xlabel='Experience', ylabel='Age'>

# %% [markdown]
# # For KNN Regression :
#     It calculate the mean of k nearest sample targeted feature value.
