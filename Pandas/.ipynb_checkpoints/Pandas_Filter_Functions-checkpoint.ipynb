# %% [markdown]
# Filter Functions :

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# Filter Data :
#   In one Column find R ration data.

# %%
df.loc[df['content_rating']=='R']
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.genre=='Adventure'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975     True
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
[df.genre=='Adventure'].index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
df.loc[df.genre=='Adventure'].index
# Out:
# Int64Index([  7,  10,  14,  15,  54,  68,  71,  85, 101, 114, 120, 128, 133,
#             137, 140, 142, 164, 179, 204, 206, 214, 222, 224, 245, 271, 299,
#             309, 310, 328, 333, 336, 339, 359, 362, 368, 376, 393, 419, 424,
#             429, 445, 454, 479, 510, 520, 522, 537, 551, 555, 564, 576, 605,
#             629, 642, 658, 662, 698, 727, 754, 758, 794, 814, 852, 891, 898,
#             900, 909, 911, 932, 935, 936, 937, 943, 953, 975],
#            dtype='int64')

# %%
df.drop(df.loc[df.genre=='Adventure'].index)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 973          7.4                            The Cider House Rules
# 974          7.4                                          Tootsie
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
df['actors_list']
# Out:
# 0      [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3      [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      [u'John Travolta', u'Uma Thurman', u'Samuel L....
#                              ...
# 974    [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975    [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976    [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977    [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978    [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# Name: actors_list, Length: 979, dtype: object

# %%
#str.contains 
df[df['actors_list'].str.contains('Marlon Brando')]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 1            9.2             The Godfather              R  Crime       175
# 51           8.5            Apocalypse Now              R  Drama       153
# 122          8.3         On the Waterfront      NOT RATED  Crime       108
# 284          8.1  A Streetcar Named Desire             PG  Drama       122
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 51   [u'Martin Sheen', u'Marlon Brando', u'Robert D...
# 122  [u'Marlon Brando', u'Karl Malden', u'Lee J. Co...
# 284  [u'Vivien Leigh', u'Marlon Brando', u'Kim Hunt...

# %% [markdown]
# And Operator(&) :

# %%
(df['content_rating']=='PG') & df['genre']=='Drama'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
df[(df['content_rating']=='PG') & (df['genre']=='Drama')]
# Out:
#      star_rating                               title content_rating  genre  \
# 32           8.6                          Casablanca             PG  Drama
# 47           8.5                    Taare Zameen Par             PG  Drama
# 221          8.1                             Solaris             PG  Drama
# 250          8.1                In the Mood for Love             PG  Drama
# 267          8.1                                Jaws             PG  Drama
# 269          8.1                               Rocky             PG  Drama
# 284          8.1            A Streetcar Named Desire             PG  Drama
# 295          8.1                     The Truman Show             PG  Drama
# 307          8.0                        East of Eden             PG  Drama
# 342          8.0                  Dead Poets Society             PG  Drama
# 347          8.0                      Days of Heaven             PG  Drama
# ...

# %% [markdown]
# OR Opeator(|) :

# %%
(df['content_rating']=='PG') | df['genre']=='Drama'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
df[(df['content_rating']=='PG') | (df['genre']=='Drama')]
# Out:
#      star_rating                                           title  \
# 5            8.9                                    12 Angry Men
# 9            8.9                                      Fight Club
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                    Forrest Gump
# 16           8.7                 One Flew Over the Cuckoo's Nest
# ..           ...                                             ...
# 972          7.4                                  Blue Valentine
# 973          7.4                           The Cider House Rules
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 9                R      Drama       139
# 12              PG     Action       124
# ...

# %%
d=df[(df['content_rating']=='PG') | (df['genre']=='Drama')]
d['duration']
# Out:
# 5       96
# 9      139
# 12     124
# 13     142
# 16     133
#       ...
# 972    112
# 973    126
# 974    116
# 975    118
# 977    114
# Name: duration, Length: 376, dtype: int64

# %% [markdown]
# Reset_index() :

# %%
d['duration'].reset_index()
# Out:
#      index  duration
# 0        5        96
# 1        9       139
# 2       12       124
# 3       13       142
# 4       16       133
# ..     ...       ...
# 371    972       112
# 372    973       126
# 373    974       116
# 374    975       118
# 375    977       114
#
# [376 rows x 2 columns]

# %% [markdown]
# Unique Function :
#   It shows the unique or distinct value/categories in the column.

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %% [markdown]
# nunique function :
#   It count the number of unique value.

# %%
len(df['genre'].unique())
# Out:
# 16

# %%
df['genre'].nunique()
# Out:
# 16

# %% [markdown]
# value_counts() :

# %%
df['content_rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# isin function() :
#   Add required keys in one list and then perform a operation.

# %%
a=['NOT RATED','TV-MA']
re_data=df.loc[(df['content_rating'].isin(a))]
re_data
# Out:
#      star_rating                            title content_rating      genre  \
# 5            8.9                     12 Angry Men      NOT RATED      Drama
# 6            8.9   The Good, the Bad and the Ugly      NOT RATED    Western
# 41           8.5                     Sunset Blvd.      NOT RATED      Drama
# 63           8.4                                M      NOT RATED      Crime
# 66           8.4              Munna Bhai M.B.B.S.      NOT RATED     Comedy
# ..           ...                              ...            ...        ...
# 665          7.7                           Lolita      NOT RATED      Drama
# 673          7.7                          Blow-Up      NOT RATED      Drama
# 763          7.6                           Hunger      NOT RATED  Biography
# 827          7.5  The Wind That Shakes the Barley      NOT RATED      Drama
# 899          7.5                      In the Loop      NOT RATED     Comedy
#
# ...

# %%
re_data.tail(20)
# Out:
#      star_rating                            title content_rating      genre  \
# 328          8.0        Aguirre, the Wrath of God      NOT RATED  Adventure
# 343          8.0               Ghost in the Shell      NOT RATED  Animation
# 405          7.9        The Bride of Frankenstein      NOT RATED     Horror
# 419          7.9                       Stagecoach      NOT RATED  Adventure
# 427          7.9     4 Months, 3 Weeks and 2 Days      NOT RATED      Drama
# 453          7.9              Toki o kakeru shojo      NOT RATED  Animation
# 478          7.8                  I Saw the Devil      NOT RATED      Crime
# 481          7.8                             Evil      NOT RATED      Drama
# 491          7.8            The Magnificent Seven      NOT RATED     Action
# 528          7.8            From Here to Eternity      NOT RATED      Drama
# 531          7.8                  The Dirty Dozen      NOT RATED     Action
# ...

# %%
Not isin Function() :

# %%
df.loc[~(df['content_rating'].isin(a))]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[~(df['content_rating'].isin(a))]['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'PG', 'UNRATED', 'APPROVED', 'PASSED', 'G', 'X', nan,
#        'GP', 'NC-17'], dtype=object)

# %%
df.loc[~(df['content_rating'].isin(a)) & (df['genre']=='Animation')]
#a=['NOT RATED','TV-MA']
# Out:
#      star_rating                               title content_rating  \
# 30           8.6                       Spirited Away             PG
# 55           8.5                       The Lion King              G
# 61           8.5              Grave of the Fireflies        UNRATED
# 64           8.4                              WALL-E              G
# 69           8.4                   Princess Mononoke          PG-13
# 81           8.4                         Toy Story 3              G
# 117          8.3                           Toy Story              G
# 126          8.3                                  Up             PG
# 131          8.3                  My Neighbor Totoro              G
# 147          8.2                Howl's Moving Castle             PG
# 160          8.2            How to Train Your Dragon             PG
# 192          8.2                        Finding Nemo              G
# 193          8.2  Nausicaa of the Valley of the Wind             PG
# ...

# %%
df.loc[~(df['content_rating'].isin(a)) & (df['genre']=='Animation')]['content_rating'].nunique()
# Out:
# 6

# %%
df.loc[~(df['content_rating'].isin(a)) & (df['genre']=='Animation')]['content_rating'].unique()
# Out:
# array(['PG', 'G', 'UNRATED', 'PG-13', 'R', 'APPROVED'], dtype=object)

# %%
df.loc[(df['star_rating']>8) & (df['genre']=='Drama')]
# Out:
#      star_rating                            title content_rating  genre  \
# 5            8.9                     12 Angry Men      NOT RATED  Drama
# 9            8.9                       Fight Club              R  Drama
# 13           8.8                     Forrest Gump          PG-13  Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R  Drama
# 17           8.7                    Seven Samurai        UNRATED  Drama
# ..           ...                              ...            ...    ...
# 284          8.1         A Streetcar Named Desire             PG  Drama
# 288          8.1                      Sling Blade              R  Drama
# 289          8.1   All Quiet on the Western Front        UNRATED  Drama
# 291          8.1                       The Return        UNRATED  Drama
# 295          8.1                  The Truman Show             PG  Drama
#
#      duration                                        actors_list
# ...

# %%
#1
df[df['actors_list'].str.contains('Tom Hanks')]
# Out:
#      star_rating                title content_rating      genre  duration  \
# 13           8.8         Forrest Gump          PG-13      Drama       142
# 36           8.6  Saving Private Ryan              R     Action       169
# 40           8.5       The Green Mile              R      Crime       189
# 81           8.4          Toy Story 3              G  Animation       103
# 117          8.3            Toy Story              G  Animation        81
# 340          8.0  Catch Me If You Can          PG-13  Biography       141
# 414          7.9          Toy Story 2              G  Animation        92
# 447          7.9     Captain Phillips          PG-13  Biography       134
# 587          7.7    Road to Perdition              R      Crime       117
# 629          7.7            Cast Away          PG-13  Adventure       143
# 644          7.7         Philadelphia          PG-13      Drama       125
# 754          7.6            Apollo 13             PG  Adventure       140
# ...

# %%
#2
df.loc[(df['star_rating']>8) & (df['genre']=='Drama') & (df['actors_list'].str.contains('Tom Hanks'))]
# Out:
#     star_rating         title content_rating  genre  duration  \
# 13          8.8  Forrest Gump          PG-13  Drama       142
#
#                                         actors_list
# 13  [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']

# %%
#3
a=df.loc[(df['star_rating']>8) & (df['genre']=='Drama')]
a.loc[a['actors_list'].str.contains('Tom Hanks')]
# Out:
#     star_rating         title content_rating  genre  duration  \
# 13          8.8  Forrest Gump          PG-13  Drama       142
#
#                                         actors_list
# 13  [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']

# %%
b=a.loc[a['actors_list'].str.contains('Tom Hanks')]
b.to_csv('Tom Hanks.csv')

# %%
b.to_excel('Tom Hanks.xlsx')
